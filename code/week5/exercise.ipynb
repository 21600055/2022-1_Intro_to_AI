# %%
from PIL import Image
from numpy import asarray
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = Image.open("./data/school.jpeg")

numpydata = asarray(img)

print(numpydata.shape)
print(type(numpydata))
plt.imshow(numpydata)
# Out:
# (666, 1000, 3)
# <class 'numpy.ndarray'>

# %%
plt.figure(figsize = (20,5))

print("shape:", numpydata.shape)
print("type:",type(numpydata))

plt.subplot(1,4,1)
plt.imshow(numpydata[300:600,300:600,:])
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(numpydata[300:600,300:600,0])
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(numpydata[300:600,300:600,1])
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(numpydata[300:600,300:600,2])
plt.axis("off")
# Out:
# shape: (666, 1000, 3)
# type: <class 'numpy.ndarray'>
# (-0.5, 299.5, 299.5, -0.5)

# %%
img2 = img.convert("L")

numpydata = asarray(img2)
print(type(numpydata))

print(numpydata.shape)
plt.imshow(numpydata,cmap = "gray")
# Out:
# <class 'numpy.ndarray'>
# (666, 1000)

# %%
print(img2.size)
img2 = img2.resize((300,200))
print(img2.size)
plt.imshow(img2,cmap="gray")
img2
# Out:
# (1000, 666)
# (300, 200)
# <PIL.Image.Image image mode=L size=300x200 at 0x11F983190>

# %%
img3 = img2.rotate(45)
img3
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x11F97F0A0>

# %%
im = asarray(Image.open("./data/girl.jpeg").convert("L"))
im2 = filters.gaussian_filter(im,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 im = asarray(Image.open("./data/girl.jpeg").convert("L"))
# ----> 2 im2 = filters.gaussian_filter(im,3)
#
# NameError: name 'filters' is not defined
